# %%
import pandas as pd

# %%
train_set = pd.read_excel("/kaggle/input/summerization/Competition CERIST -- Summarization/Dataset 1 Arabic (EACS)/dataset_EASC_v1.0_train.xlsx")
test_set = pd.read_excel("/kaggle/input/summerization/Competition CERIST -- Summarization/Dataset 1 Arabic (EACS)/dataset_EASC_v1.0_test.xlsx")

# %%
train_set.head()
# Out:
#                                       Document Sents                Summary
# 0  السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...           1,2,5,7,9,11
# 1  السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...              1,2,5,7,9
# 2  السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...  1,2,5,6,8,14,18,27,31
# 3  السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...           1,2,5,6,7,14
# 4  السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...              1,2,6,7,9

# %%
train_set.columns
# Out:
# Index(['Document Sents', 'Summary'], dtype='object')

# %%
train_set.iloc[0,0]
# Out:
# 'السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات دقيقة من الماء أو الجليد أو كليهما معا يتراوح قطرها ما بين 1 إلى 100 ميكرون تبدو سابحة في الجو على ارتفاعات مختلفة كما تبدو بأشكال وأحجام وألوان متباينة، كما تحتوي على بخار الماء والغبار وكمية هائلة من الهواء الجاف ومواد سائلة أخرى وجزيئات صلبة منبعثة من الغازات الصناعية\nتعتبر السحب عبارة عن شكل من أشكال الرطوبة الجوية التي يمكن رؤيتها بالعين المجردة، حيث أن الشمس، التي تعتبر المحرك الأساسي لدورة الماء، تقوم بتسخين المحيطات التي تحول جزءا من مياهها من حالتها السائلة إلى بخار، فتقوم التيارات الهوائية المتصاعدة بأخذ بخار الماء إلى داخل الغلاف الجوي (حيث درجات الحرارة المنخفضة) فيتكاثف الهواء المشبع ببخار الماء مكونا بذلك جزيائات الماء السائلة أو المتجمدة فتمتزج بذرات الغبار مشكلة بذلك السحب\nبما أن درجة كثافة السحب هي من 10 إلى 100 مرة أقل من درجة كثافة الهواء فإنها تطفوا في السماء، أما ما يفسر تحرك السحب عبر الرياح هو الحركة الدائمة لجزيئات الهواء التي تدفع كل الكتل التي تحتك بها بما في ذلك السحب\nتنقسم السحب حسب ارتفاعها إلى 3 أقسام: السحب عالية الارتفاع، السحب متوسطة الارتفاع والسحب منخفضة الارتفاع\nتنقسم كل مجموعة من المجموعات الثلاثة إلى عدة أنواع.\nالبركان هو ذلك المكان الذي تخرج أو تنبعث منه المواد الصهيرية الحارة مع الأبخرة والغازات المصاحبة لها على عمق من والقشرة الأرضية ويحدث ذلك خلال فوهات أو شقوق\nوتتراكم المواد المنصهرة أو تنساب حسب نوعها لتشكل أشكالا أرضية مختلفة منها التلال المخروطية أو الجبال البركانية العالية\nسجل التاريخ حدوث هزات أرضية قبل حدوث البراكين، حيث سبق حدوث انفجار هاواي نوعان من الهزات الأرضية نوع قريب من السطح لا يتعدى بعد مركز الزلزال فيه عن 8 كيلومترات عن السطح، ونوع حدث على أعماق سحيقة على بعد 60 كيلومترا تحت سطح الأرض\nوفي بعض الحالات سبقت الهزات انفجار البراكين بعدة سنوات ومثال تلك الهزات الأرضية التي استمرت 16 عاما قبل ثوران بركان فيزوف (79 ق\nم) وكذلك الهزات الأرضية التي استمرت عدة سنوات قبل حدوث انفجار بركان كيلوا Kilau في هاواي\nوفي هذا المجال قام (مركز رصد البراكين) في هاواي بعدة دراسات ميدانية حول هذه الظاهرة عام 1942 حيث سجل حدوث هزات أرضية عنيفة في مونالوا Maunaloa على أبعاد سحيقة من سطح الأرض تتراوح بين 40-50 كيلومترا\nوفي 22 فبراير من تلك السنة حدثت هزات أرضية قريبة من السطح على جوانب الجبل في مناطق الشقوق فيه\nكانت هذه الهزات إنذارا لحدوث ثورة البركان التي حصلت على جوانب الجبل على ارتفاع 2500-3000م، بتاريخ 26 أبريل 1942\nولكن هل يمكن التنبؤ بصورة دقيقة بوقت حدوث النشاطات البركانية ؟\nومن الدراسات الحديثة في هذا المجال استخدامالأقمار الصناعية حيث يمكن بواسطتها استعمال جهاز قياس الميلTilt meter الذي يدلنا على تغير ميل التراكيب الجيولوجية نتيجة اندفاع الصهارة من اسفل إلى أعلى وحدوث تفلطح في المنطقة التي يبدأ يتكون فيها المخروط البركاني والذي تخرج منه الحمم\nإن الاهتمام العالمي بهذا الخصوص أدى إلى تأسيس معاهد تختص بدراسة الظواهر الفجائية مثل الإنفجارات البركانية ففي مدينة كامبردج في الولايات المتحدة معهد يضم نخبة من الباحثين وعلماء البراكين والجيولوجيا وتتصل به شبكات عالمية تزوده بالمعلومات حول الهزات الأرضية والثورانات البركانية وأي عوارض أخرى فجائية تحدث في القشرة الأرضية في أماكن مختلفة من العالم\nويتم مقارنة ودراسة هذه المعلومات أولا بأول للوصول إلى تصورات متكاملة حول هذا الموضوع.'

# %%
test_set.head()
# Out:
#                                       Document Sents  \
# 0  الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 1  الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 2  الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 3  الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 4  الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
#
#                         Summary
# 0           0,3,7,9,11,14,16,18
# 1     0,3,7,9,11,14,16,18,23,28
# 2  0,3,7,9,11,14,16,20,24,25,31
# 3        0,3,7,9,11,14,16,19,25
# 4  0,3,7,9,11,14,16,17,19,25,35

# %%
def split_column(df,column, split_car):
# converting to dict
    index_value = df[column].to_dict()
    for key, value in index_value.items():
        if split_car == ",":
            list_index = index_value[key].split(split_car)
            index_value[key] = list(map(int,list_index))
        else :
            list_text = index_value[key].split(split_car)
            index_value[key] = list_text
    return index_value

# %%
def extract_summary(df):
    summary_text={}
    summary_index = split_column(df, 'Summary', ',')
    document_index = split_column(df, 'Document Sents', '\n')
    for (index1,indices),(index2, texts) in zip(summary_index.items(), document_index.items()):
        summary_text[index1] = ""
        for i in indices :
            summary_text[index1] += texts[i]
    return summary_text

# %%
train_summary_dict = extract_summary(train_set)
test_summary_dict = extract_summary(test_set)

# %%
summary_train_df = pd.DataFrame.from_dict(train_summary_dict,orient ='index', columns = ['summary'])
summary_test_df = pd.DataFrame.from_dict(test_summary_dict,orient ='index', columns = ['summary'])

# %%
train_df = pd.concat([train_set, summary_train_df], axis=1)
test_df = pd.concat([test_set, summary_test_df], axis=1)

# %%
train_df
# Out:
#                                          Document Sents  \
# 0     السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...
# 1     السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...
# 2     السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...
# 3     السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...
# 4     السحابة أو الغيمة عبارة عن تجمع مرئي لجزيئات د...
# ...                                                 ...
# 2310  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2311  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2312  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2313  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2314  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
#
#                                   Summary  \
# 0                            1,2,5,7,9,11
# 1                               1,2,5,7,9
# 2                   1,2,5,6,8,14,18,27,31
# 3                            1,2,5,6,7,14
# 4                               1,2,6,7,9
# ...                                   ...
# 2310              0,2,8,11,19,20,26,28,38
# 2311  0,2,8,11,19,34,41,42,43,44,46,48,49
# 2312        0,2,8,11,19,20,21,23,24,25,30
# 2313        0,2,8,11,19,20,21,22,26,35,41
# 2314              0,2,8,11,19,23,25,27,30
#
#                                                 summary
# 0     تعتبر السحب عبارة عن شكل من أشكال الرطوبة الجو...
# 1     تعتبر السحب عبارة عن شكل من أشكال الرطوبة الجو...
# 2     تعتبر السحب عبارة عن شكل من أشكال الرطوبة الجو...
# 3     تعتبر السحب عبارة عن شكل من أشكال الرطوبة الجو...
# 4     تعتبر السحب عبارة عن شكل من أشكال الرطوبة الجو...
# ...                                                 ...
# 2310  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2311  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2312  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2313  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
# 2314  ساعة بيج بن الشهيرة في لندن، بدأ عملها 3 يونيو...
#
# [2315 rows x 3 columns]

# %%
test_df
# Out:
#                                         Document Sents  \
# 0    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 1    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 2    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 3    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 4    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# ..                                                 ...
# 380  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 381  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 382  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 383  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 384  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
#
#                                   Summary  \
# 0                     0,3,7,9,11,14,16,18
# 1               0,3,7,9,11,14,16,18,23,28
# 2            0,3,7,9,11,14,16,20,24,25,31
# 3                  0,3,7,9,11,14,16,19,25
# 4            0,3,7,9,11,14,16,17,19,25,35
# ..                                    ...
# 380        0,2,3,4,6,12,14,15,17,20,21,27
# 381           0,2,3,4,6,12,14,15,17,18,19
# 382           0,2,3,4,6,12,14,15,17,18,19
# 383  0,2,3,4,6,12,14,15,17,18,19,21,25,29
# 384     0,2,3,4,6,12,14,15,17,18,19,21,23
#
#                                                summary
# 0    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 1    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 2    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 3    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# 4    الناي آلة نفخية تعد بحق أقدم آلة موسيقية في ال...
# ..                                                 ...
# 380  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 381  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 382  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 383  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
# 384  في وحدة خدمات المشتركين بكهرباء عسير، صباح الي...
#
# [385 rows x 3 columns]
